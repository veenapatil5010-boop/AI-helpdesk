# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\manth\OneDrive\Desktop\AI_Helpdesk_Project\dataset\aa_dataset-tickets-multi-lang-5-2-50-version.csv")

print(df.head())

# %%
import pandas as pd

df = pd.read_csv("cleaned_english_tickets_dataset.csv")

print(df.head())

# %%
df = df[['subject', 'body', 'queue', 'priority']]
